# %%
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000
(X_train, y_train), (X_test, y_test) = reuters.load_data(num_words=vocab_size)

# %%
max_len = 200
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 128, input_shape=(max_len,)))
model.add(Bidirectional(GRU(64, return_sequences=True)))
model.add(GRU(32))
model.add(Dropout(0.5))
model.add(Dense(46, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:103: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 200, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 200, 128)       │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 32)             │        15,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 46)             │         1,518 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,371,566 (5.23 MB)
#  Trainable params: 1,371,566 (5.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=25, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.3808 - loss: 2.6549 - val_accuracy: 0.5242 - val_loss: 1.9203
# Epoch 2/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5381 - loss: 1.8858 - val_accuracy: 0.5726 - val_loss: 1.7346
# Epoch 3/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5768 - loss: 1.7034 - val_accuracy: 0.5504 - val_loss: 1.7624
# Epoch 4/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6003 - loss: 1.6046 - val_accuracy: 0.5954 - val_loss: 1.6031
# Epoch 5/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6444 - loss: 1.4431 - val_accuracy: 0.5826 - val_loss: 1.6287
# Epoch 6/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6703 - loss: 1.3329 - val_accuracy: 0.6233 - val_loss: 1.5840
# Epoch 7/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6987 - loss: 1.2338 - val_accuracy: 0.6238 - val_loss: 1.5675
# Epoch 8/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7268 - loss: 1.1338 - val_accuracy: 0.6177 - val_loss: 1.6103
# Epoch 9/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7439 - loss: 1.0652 - val_accuracy: 0.6377 - val_loss: 1.5613
# Epoch 10/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7635 - loss: 0.9947 - val_accuracy: 0.6505 - val_loss: 1.5917
# Epoch 11/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7756 - loss: 0.9391 - val_accuracy: 0.6283 - val_loss: 1.6279
# Epoch 12/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7905 - loss: 0.8710 - val_accuracy: 0.6255 - val_loss: 1.6389
# Epoch 13/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8013 - loss: 0.8335 - val_accuracy: 0.6377 - val_loss: 1.6596
# Epoch 14/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8170 - loss: 0.7797 - val_accuracy: 0.6422 - val_loss: 1.6337
# Epoch 15/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8224 - loss: 0.7458 - val_accuracy: 0.6283 - val_loss: 1.7633
# Epoch 16/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8342 - loss: 0.6984 - val_accuracy: 0.6461 - val_loss: 1.6566
# Epoch 17/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8408 - loss: 0.6733 - val_accuracy: 0.6483 - val_loss: 1.6931
# Epoch 18/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8475 - loss: 0.6448 - val_accuracy: 0.6405 - val_loss: 1.7219
# Epoch 19/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8611 - loss: 0.6006 - val_accuracy: 0.6511 - val_loss: 1.7285
# Epoch 20/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8643 - loss: 0.5689 - val_accuracy: 0.6422 - val_loss: 1.7969
# Epoch 21/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8690 - loss: 0.5590 - val_accuracy: 0.6472 - val_loss: 1.7506
# Epoch 22/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8707 - loss: 0.5413 - val_accuracy: 0.6461 - val_loss: 1.7852
# Epoch 23/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8800 - loss: 0.5075 - val_accuracy: 0.6589 - val_loss: 1.7553
# Epoch 24/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8824 - loss: 0.4915 - val_accuracy: 0.6622 - val_loss: 1.7963
# Epoch 25/25
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8948 - loss: 0.4609 - val_accuracy: 0.6561 - val_loss: 1.7917

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Accurcacy:", acc)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6354 - loss: 1.9215
# Accurcacy: 0.6353517174720764
